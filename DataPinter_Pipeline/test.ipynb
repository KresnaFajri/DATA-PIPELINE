# %%
import duckdb

DB_PATH=r"C:\KRESNA\ANALYSIS\Ads Analysis\DUCKDB_ADS_DATASET\campaign.duckdb"
con = duckdb.connect(DB_PATH)
con.sql("CALL start_ui();")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────────────────────────────┐
# │                result                │
# │               varchar                │
# ├──────────────────────────────────────┤
# │ UI started at http://localhost:4213/ │
# └──────────────────────────────────────┘

# %%
import duckdb

DB_PATH=r"C:\KRESNA\ANALYSIS\SKINCARE\SKINCARE_DUCKDB\haircare.duckdb"
con = duckdb.connect(DB_PATH)
con.sql("CALL start_ui();")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────────────────────────────┐
# │                result                │
# │               varchar                │
# ├──────────────────────────────────────┤
# │ UI started at http://localhost:4213/ │
# └──────────────────────────────────────┘

# %%
import pandas as pd
BRAND_PATH = r"C:\KRESNA\Tools-20251201T015117Z-1-001\Tools\DATA PIPELINE\DATA_COSMETICS_BRAND.csv"
brand = pd.read_csv(BRAND_PATH)
brand
# Out:
#                        product_brands
# 0                                LIZY
# 1                             PREDIRE
# 2              ANGEL AESTHETIC CLINIC
# 3                             TRISENA
# 4                         BY THE BEAU
# ...                               ...
# 32125                         REGAZZA
# 32126  SOLCARE SOLUTION FOR YOUR SKIN
# 32127                SL SHEREA LYXERA
# 32128                             LSY
# 32129         DEZZYRA BEAUTY SKINCARE
#
# [32130 rows x 1 columns]

# %%
from pptx import Presentation
BASE_PATH =r"C:\KRESNA\Tools-20251201T015117Z-1-001\Tools\DATA PIPELINE\DataPinter_Pipeline\dynamic-ppt\asset\TEMPLATE_AUTO_PPT.pptx"

prs = Presentation(BASE_PATH)
slide = prs.slides[4]

for shape in slide.shapes:
    print(shape.name)
# Out:
# TextBox 2
# Picture 3
# TextBox 4
# TextBox 5
